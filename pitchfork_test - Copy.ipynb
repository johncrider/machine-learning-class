# %%
import pandas as pd
import numpy as np

# %%
pitchfork_df = pd.read_csv('pitchfork1.csv')
pitchfork_df=pitchfork_df.append(pd.read_csv('pitchfork2.csv'))
pitchfork_df=pitchfork_df.append(pd.read_csv('pitchfork3.csv'))
pitchfork_df=pitchfork_df.append(pd.read_csv('pitchfork4.csv'))
pitchfork_df = pitchfork_df.reset_index()
print(pitchfork_df.shape)
# Out:
# (12154, 8)

# %%
import matplotlib
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# Hmmm. Why are some of the scores Nan? I am going to turn them into -1
# for now. I think that we should either get a real score for them, or remove them
# from the dataset. Other thoughts?
pitchfork_df.head()
values = {'score':-1}
pitchfork_df = pitchfork_df.fillna(value=values)
#pitchfork_df['score'].values
misc = {'genre':'Misc'}
pitchfork_df = pitchfork_df.fillna(value=misc)

# %%
sns.distplot(pitchfork_df['score'].values)
# Out:
# C:\Users\sanderdv\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
print(np.std(pitchfork_df['score'].values))
print(np.mean(pitchfork_df['score'].values))
print(pitchfork_df['album'][:2])
print(pitchfork_df['album'][:2][0])
# Out:
# 1.1022086757701128
# 7.099473424387033
# 0                 DJ-Kicks
# 1    I Trawl the Megahertz
# Name: album, dtype: object
# DJ-Kicks

# %%
pitchfork_df.head()
# Out:
#    index         artist                  album  score       genre  \
# 0      0    Laurel Halo               DJ-Kicks    7.7  Electronic
# 1      1  Prefab Sprout  I Trawl the Megahertz    8.5  Electronic
# 2      2     USA/Mexico              Matamoros    7.3        Rock
# 3      3        Tamaryn   Dreaming in the Dark    6.5        Rock
# 4      4  Nilüfer Yanya          Miss Universe    8.3     Pop/R&B
#
#                                               review  best           date
# 0  On her first commercial mix album, the produce...     0  March 23 2019
# 1  Best new reissue This lost Prefab Sprout album...     1  March 23 2019
# 2  USA/Mexico are sludgy, nasty, and unclassifiab...     0  March 23 2019
# 3  On her new album, Tamaryn aims for sky-high '8...     0  March 23 2019
# 4  Best new music The rapturous debut from the Br...     1  March 22 2019

# %%
# I picked 7.0 as an arbitrary cutoff between good and bad.

pitchfork_df['rating'] = np.where(pitchfork_df['score']>=7.0,1,np.where(pitchfork_df['score']<4.0,-1,0))

# %%
pitchfork_df.head()
# Out:
#    index         artist                  album  score       genre  \
# 0      0    Laurel Halo               DJ-Kicks    7.7  Electronic
# 1      1  Prefab Sprout  I Trawl the Megahertz    8.5  Electronic
# 2      2     USA/Mexico              Matamoros    7.3        Rock
# 3      3        Tamaryn   Dreaming in the Dark    6.5        Rock
# 4      4  Nilüfer Yanya          Miss Universe    8.3     Pop/R&B
#
#                                               review  best           date  \
# 0  On her first commercial mix album, the produce...     0  March 23 2019
# 1  Best new reissue This lost Prefab Sprout album...     1  March 23 2019
# 2  USA/Mexico are sludgy, nasty, and unclassifiab...     0  March 23 2019
# 3  On her new album, Tamaryn aims for sky-high '8...     0  March 23 2019
# 4  Best new music The rapturous debut from the Br...     1  March 22 2019
#
#    rating
# 0       1
# 1       1
# 2       1
# 3       0
# 4       1

# %%
pitchfork_df['review'][0][0]
# Out:
# 'O'

# %%
def cleanReview(stringToClean):
    return prepStringForProcessing(stringToClean)

def prepStringForProcessing(inputString):
    # this code cleans a string. It takes
    # a string and removes the puncuation 
    # from the string. The cleaned string 
    # is returned
    
    # remove puncuation
    outputString = inputString.replace(',','')
    outputString = outputString.replace('.','')
    outputString = outputString.replace(':','')
    outputString = outputString.replace(';','')
    outputString = outputString.replace('@','')
    outputString = outputString.replace('"','')
    outputString = outputString.replace("'","")
    outputString = outputString.replace("'","")
    outputString = outputString.replace('?','')
    outputString = outputString.replace('!','')
    outputString = outputString.replace('#','')
    outputString = outputString.replace('%','')
    outputString = outputString.replace('&','')
    outputString = outputString.replace('$','')
    outputString = outputString.replace('^','')
    outputString = outputString.replace('*','')
    outputString = outputString.replace('(','')
    outputString = outputString.replace(')','')
    outputString = outputString.replace('!','')
    outputString = outputString.replace('-','')
    return outputString.lower();

# %%
for i in range(0,len(pitchfork_df)-1):
    pitchfork_df['review'][i] = cleanReview(pitchfork_df['review'][i])
# Out:
# C:\Users\sanderdv\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
pitchfork_df.head()
# Out:
#    index         artist                  album  score       genre  \
# 0      0    Laurel Halo               DJ-Kicks    7.7  Electronic
# 1      1  Prefab Sprout  I Trawl the Megahertz    8.5  Electronic
# 2      2     USA/Mexico              Matamoros    7.3        Rock
# 3      3        Tamaryn   Dreaming in the Dark    6.5        Rock
# 4      4  Nilüfer Yanya          Miss Universe    8.3     Pop/R&B
#
#                                               review  best           date  \
# 0  on her first commercial mix album the producer...     0  March 23 2019
# 1  best new reissue this lost prefab sprout album...     1  March 23 2019
# 2  usa/mexico are sludgy nasty and unclassifiable...     0  March 23 2019
# 3  on her new album tamaryn aims for skyhigh 80sg...     0  March 23 2019
# 4  best new music the rapturous debut from the br...     1  March 22 2019
#
#    rating
# 0       1
# 1       1
# 2       1
# 3       0
# 4       1

# %%
import nltk
from nltk.stem.porter import PorterStemmer

def tokenizeStem(text):
    tokens = nltk.word_tokenize(text)
    stems = []
    for item in tokens:
        stems.append(PorterStemmer().stem(item))
    return stems

# %%
from sklearn.model_selection import train_test_split

from sklearn.feature_extraction.text import TfidfVectorizer,  CountVectorizer,TfidfTransformer  
from sklearn.model_selection import GridSearchCV  
from sklearn.naive_bayes import MultinomialNB  

from sklearn.pipeline import Pipeline  
from time import time  
from sklearn.svm import LinearSVC

# %%
minisize = .99

t0 = time()  
X = pitchfork_df['review']
y = pitchfork_df['rating']
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=minisize, random_state=42)
X_train_mini, X_test_mini, y_train_mini, y_test_mini = train_test_split(X_test, y_test,test_size=0.25)

pipeline = Pipeline([
    ('vec', CountVectorizer(tokenizer=tokenizeStem, max_df=0.5, max_features=700000, min_df=1, ngram_range=(1,3))),
    ('tfidf', TfidfTransformer()), 
    ('clf', LinearSVC())])
pipeline.fit(X_train_mini, y_train_mini)
print(pipeline)
print(pipeline.score(X_test_mini, y_test_mini))

print("done in {0}s".format(time() - t0))
# Out:
# Pipeline(memory=None,
#      steps=[('vec', CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=0.5, max_features=700000, min_df=1,
#         ngram_range=(1, 3), preprocessor=None, stop_words=None,
#         stri...ax_iter=1000,
#      multi_class='ovr', penalty='l2', random_state=None, tol=0.0001,
#      verbose=0))])
# 0.747424393486208
# done in 652.9167854785919s

# %%
print(pipeline.score(X_test_mini, y_test_mini))
# Out:
# 0.747424393486208

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\sanderdv\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
#order by score from high to low
ranked = pitchfork_df.sort_values(by='score', ascending=False)

# %%
#show top 50 scores
ranked.head(50)
# Out:
#        index                   artist  \
# 2612    2612                    Björk
# 8843    2749  Talk Talk / Mark Hollis
# 2533    2533                   Weezer
# 3578     530                   Prince
# 8933    2839                  Nirvana
# 11299   2161          The Stone Roses
# 9941     803                   Weezer
# 11302   2164              The Beatles
# 11304   2166              The Beatles
# 1543    1543                Metallica
# 3633     585                Metallica
# 11306   2168              The Beatles
# 11307   2169              The Beatles
# 11308   2170              The Beatles
# 5932    2884                    Slint
# 2493    2493     The Notorious B.I.G.
# 11309   2171              The Beatles
# 176      176           Alice Coltrane
# 3573     525                   Prince
# 4565    1517       The Rolling Stones
# 10496   1358       The Rolling Stones
# 581      581                PJ Harvey
# 3370     322               Neil Young
# 8677    2583                      Can
# 5192    2144             Public Enemy
# 5197    2149   The Velvet Underground
# 3574     526                   Prince
# 9782     644   The Dismemberment Plan
# 1683    1683               The Smiths
# 8208    2114      My Bloody Valentine
# 8803    2709           The Beach Boys
# 3422     374                Kate Bush
# 2916    2916                Bob Dylan
# 916      916                 The Band
# 9877     739               Kanye West
# 3577     529  Prince / The Revolution
# 2499    2499            Elliott Smith
# 942      942                     Hole
# 7965    1871                      GZA
# 3812     764          Michael Jackson
# 3071      23                Brian Eno
# 5957    2909                Mobb Deep
# 11360   2222                Radiohead
# 10421   1283                 The Cure
# 4091    1043     A Tribe Called Quest
# 7417    1323                      Nas
# 4051    1003            John Coltrane
# 7357    1263            Fleetwood Mac
# 2691    2691               X-Ray Spex
# 12004   2866             Beastie Boys
#
#                                                    album  score         genre  \
# 2612                                           Homogenic   10.0    Electronic
# 8843                        Laughing Stock / Mark Hollis   10.0          Rock
# 2533                                 Weezer (Blue Album)   10.0          Rock
# 3578                                          Dirty Mind   10.0       Pop/R&B
# 8933                Nevermind [20th Anniversary Edition]   10.0          Rock
# 11299                                    The Stone Roses   10.0          Rock
# 9941   Pinkerton [Deluxe Edition] / Death to False Metal   10.0          Rock
# 11302                                         Abbey Road   10.0          Rock
# 11304                                        The Beatles   10.0          Rock
# 1543                                   Master of Puppets   10.0         Metal
# 3633                     Kill 'Em All/Ride the Lightning   10.0         Metal
# 11306                               Magical Mystery Tour   10.0          Rock
# 11307              Sgt. Pepper's Lonely Hearts Club Band   10.0          Rock
# 11308                                           Revolver   10.0          Rock
# 5932                                          Spiderland   10.0          Rock
# 2493                                        Ready to Die   10.0           Rap
# 11309                                        Rubber Soul   10.0          Rock
# 176                             Journey in Satchidananda   10.0          Jazz
# 3573                                   Sign o’ the Times   10.0       Pop/R&B
# 4565                                      Sticky Fingers   10.0          Rock
# 10496                 Exile on Main St. [Deluxe Edition]   10.0          Rock
# 581                                            Rid of Me   10.0          Rock
# 3370                                 Tonight's the Night   10.0          Rock
# 8677                Tago Mago [40th Anniversary Edition]   10.0  Experimental
# 5192   It Takes a Nation of Millions to Hold Us Back/...   10.0           Rap
# 5197   The Velvet Underground – 45th Anniversary Supe...   10.0          Rock
# 3574                                                1999   10.0       Pop/R&B
# 9782                       Emergency & I [Vinyl Reissue]   10.0          Rock
# 1683                                   The Queen Is Dead   10.0          Rock
# 8208           Isn't Anything / Loveless / EPs 1988-1991   10.0  Experimental
# 8803                                  The Smile Sessions   10.0          Rock
# 3422                                      Hounds of Love   10.0       Pop/R&B
# 2916                                 Blood on the Tracks   10.0          Rock
# 916                                             The Band   10.0          Rock
# 9877                   My Beautiful Dark Twisted Fantasy   10.0           Rap
# 3577                                         Purple Rain   10.0       Pop/R&B
# 2499                         Either/Or: Expanded Edition   10.0          Rock
# 942                                    Live Through This   10.0          Rock
# 7965             Liquid Swords: Chess Box Deluxe Edition   10.0           Rap
# 3812                                        Off the Wall   10.0       Pop/R&B
# 3071                                 Another Green World   10.0  Experimental
# 5957               The Infamous / The Infamous Mobb Deep   10.0           Rap
# 11360                  Kid A: Special Collectors Edition   10.0          Rock
# 10421                    Disintegration [Deluxe Edition]   10.0          Rock
# 4091   People's Instinctive Travels and the Paths of ...   10.0           Rap
# 7417                                            Illmatic   10.0           Rap
# 4051                A Love Supreme: The Complete Masters   10.0          Jazz
# 7357                                             Rumours   10.0          Rock
# 2691                                Germfree Adolescents   10.0          Rock
# 12004                                    Paul's Boutique   10.0           Rap
#
#                                                   review  best  \
# 2612   homogenic embraced all of björk’s most provoca...     0
# 8843   best new reissue best new reissue 1 / 2 albums...     1
# 2533   weezer’s 1994 debut filled with geeky humor de...     0
# 3578   prince’s first fully actualized album is an un...     0
# 8933   twenty years on the album that changed the cou...     0
# 11299  best new reissue a badly needed remaster of th...     1
# 9941   best new reissue 1 / 2 albums weezers overlook...     1
# 11302  the perfect ending to a recording career this ...     0
# 11304  indulgent sprawling overflowing with ideas and...     0
# 1543   best new reissue in 1986 metallica released in...     1
# 3633   1 / 2 albums in a monumental onetwo punch meta...     0
# 11306  the only american release to become part of th...     0
# 11307  though it has perhaps slipped in estimation si...     0
# 11308  as they devoted more time to the studio the be...     0
# 5932   best new reissue slints landmark second album ...     1
# 2493   today we commemorate the 20th anniversary of t...     0
# 11309  the beatles first undisputed masterpiece is th...     0
# 176    each sunday pitchfork takes an indepth look at...     0
# 3573   choosing a single high point from prince’s glo...     0
# 4565   best new reissue sticky fingers came at a time...     1
# 10496  best new reissue the 1972 classic is given a r...     1
# 581    each sunday pitchfork takes an indepth look at...     0
# 3370   neil youngs tonights the night is a harrowing ...     0
# 8677   cans 1971 album tago mago freshly reissued in ...     0
# 5192   best new reissue best new reissue 1 / 2 albums...     1
# 5197   best new reissue the velvet underground’s sixd...     1
# 3574   1999 is the greatest album ever made about par...     0
# 9782   best new reissue one of the alltime great indi...     1
# 1683   newly reissued as a boxed set the smiths’ 1986...     0
# 8208   best new reissue best new reissue best new rei...     1
# 8803   best new reissue conceived recorded and ultima...     1
# 3422   with her selfproduced fifth album kate bush be...     0
# 2916   bob dylan’s moody 1975 epic is often referred ...     0
# 916    each sunday pitchfork takes an indepth look at...     0
# 9877   best new music kanyes big year culminates in a...     1
# 3577   purple rain was a landmark that solidified pri...     0
# 2499   best new reissue the 20th anniversary remaster...     1
# 942    each sunday pitchfork takes an indepth look at...     0
# 7965   best new reissue as a solo artist gza was esse...     1
# 3812   best new reissue off the wall is the sound of ...     1
# 3071   brian eno has done everything from producing h...     0
# 5957   best new reissue 1 / 2 albums havoc and prodig...     1
# 11360  best new reissue capitol follows its excavatio...     1
# 10421  best new reissue the cure’s 1989 album release...     1
# 4091   best new reissue a tribe called quests seminal...     1
# 7417   best new reissue the 1994 hiphop landmark is r...     1
# 4051   best new reissue a love supreme is john coltra...     1
# 7357   best new reissue upon its release in 1977 rumo...     1
# 2691   xray spex’s debut album is a brash vivid maste...     0
# 12004  best new reissue the beastie boys’ landmark se...     1
#
#                     date  rating
# 2612     February 5 2017       1
# 8843     October 21 2011       1
# 2533    February 26 2017       1
# 3578       April 29 2016       1
# 8933   September 27 2011       1
# 11299  September 11 2009       1
# 9941     November 3 2010       1
# 11302  September 10 2009       1
# 11304  September 10 2009       1
# 1543     December 2 2017       1
# 3633       April 13 2016       1
# 11306   September 9 2009       1
# 11307   September 9 2009       1
# 11308   September 9 2009       1
# 5932       April 16 2014       1
# 2493        March 9 2017       1
# 11309   September 9 2009       1
# 176      February 3 2019       1
# 3573       April 30 2016       1
# 4565        June 19 2015       1
# 10496        May 19 2010       1
# 581    September 16 2018       1
# 3370        June 26 2016       1
# 8677     December 9 2011       1
# 5192    November 25 2014       1
# 5197    November 24 2014       1
# 3574       April 30 2016       1
# 9782     January 11 2011       1
# 1683     October 22 2017       1
# 8208         May 11 2012       1
# 8803     November 2 2011       1
# 3422        June 12 2016       1
# 2916     October 30 2016       1
# 916         June 10 2018       1
# 9877    November 22 2010       1
# 3577       April 29 2016       1
# 2499        March 7 2017       1
# 942          June 3 2018       1
# 7965        July 27 2012       1
# 3812    February 24 2016       1
# 3071   September 18 2016       1
# 5957        April 9 2014       1
# 11360     August 25 2009       1
# 10421       June 10 2010       1
# 4091    November 13 2015       1
# 7417     January 23 2013       1
# 4051    November 25 2015       1
# 7357     February 8 2013       1
# 2691     January 15 2017       1
# 12004   February 13 2009       1

# %%
#find all unique genres
genres = pitchfork_df.genre.unique()

# %%
genres
# Out:
# array(['Electronic', 'Rock', 'Pop/R&B', 'Rap', 'Jazz', 'Experimental',
#        'Metal', 'Folk/Country', 'Misc', 'Global'], dtype=object)

# %%
#Create line graph of scores by genre
ranked.groupby(['score','genre']).size().unstack(fill_value=0).plot()

# %%
#Create list with the average album score by genre
avg_score = ranked.groupby(['genre'])['score'].agg(lambda x: x.unique().mean())

# %%
avg_score
# Out:
# genre
# Electronic      5.864384
# Experimental    6.721053
# Folk/Country    6.766000
# Global          7.276667
# Jazz            7.553846
# Metal           6.570909
# Misc            6.082540
# Pop/R&B         6.389062
# Rap             5.997183
# Rock            5.890000
# Name: score, dtype: float64

# %%
#Create scatter plot of average score by genre
plt.title("Average Score by Genre") #add title

plt.xlim(left=5, right=9) #set table start and end values

plt.xlabel("Averages") #add x-axis label

plt.grid(b=True, which='major', axis='both') #add grid lines

plt.scatter(avg_score[:],avg_score.index)

# %%
#Create dataframe of albums with a perfect score of 10
perfect = pd.DataFrame(data=None, index=None, columns=pitchfork_df.columns)
for i in range(len(pitchfork_df)):
    if pitchfork_df['score'][i] == 10.0:
        perfect = perfect.append(pitchfork_df.loc[i])

# %%
perfect.shape
# Out:
# (79, 9)

# %%
perfect
# Out:
#       index                                artist  \
# 176     176                        Alice Coltrane
# 239     239                             Talk Talk
# 456     456                         Talking Heads
# 490     490                           Bikini Kill
# 556     556                            De La Soul
# 581     581                             PJ Harvey
# 916     916                              The Band
# 942     942                                  Hole
# 1057   1057                             Liz Phair
# 1070   1070  Captain Beefheart and His Magic Band
# 1224   1224                     Bruce Springsteen
# 1543   1543                             Metallica
# 1683   1683                            The Smiths
# 2035   2035                         Guns N' Roses
# 2095   2095               Prince / The Revolution
# 2109   2109                             Radiohead
# 2177   2177                      Ghostface Killah
# 2431   2431                           Glenn Gould
# 2493   2493                  The Notorious B.I.G.
# 2499   2499                         Elliott Smith
# 2533   2533                                Weezer
# 2612   2612                                 Björk
# 2691   2691                            X-Ray Spex
# 2907   2907                      Public Image Ltd
# 2916   2916                             Bob Dylan
# 3071     23                             Brian Eno
# 3167    119                         Stevie Wonder
# 3246    198                           Nina Simone
# 3370    322                            Neil Young
# 3422    374                             Kate Bush
# ...     ...                                   ...
# 7357   1263                         Fleetwood Mac
# 7417   1323                                   Nas
# 7440   1346                               J Dilla
# 7505   1411                              D’Angelo
# 7580   1486                      William Basinski
# 7965   1871                                   GZA
# 8208   2114                   My Bloody Valentine
# 8677   2583                                   Can
# 8803   2709                        The Beach Boys
# 8843   2749               Talk Talk / Mark Hollis
# 8933   2839                               Nirvana
# 9782    644                The Dismemberment Plan
# 9877    739                            Kanye West
# 9941    803                                Weezer
# 10421  1283                              The Cure
# 10496  1358                    The Rolling Stones
# 10756  1618                              Pavement
# 10776  1638                         Spiritualized
# 11299  2161                       The Stone Roses
# 11302  2164                           The Beatles
# 11304  2166                           The Beatles
# 11306  2168                           The Beatles
# 11307  2169                           The Beatles
# 11308  2170                           The Beatles
# 11309  2171                           The Beatles
# 11315  2177                           The Beatles
# 11360  2222                             Radiohead
# 11520  2382                                R.E.M.
# 11863  2725                      Serge Gainsbourg
# 12004  2866                          Beastie Boys
#
#                                                    album  score         genre  \
# 176                             Journey in Satchidananda   10.0          Jazz
# 239                                       Spirit of Eden   10.0          Rock
# 456                                      Remain in Light   10.0          Rock
# 490                                          The Singles   10.0          Rock
# 556                               3 Feet High and Rising   10.0           Rap
# 581                                            Rid of Me   10.0          Rock
# 916                                             The Band   10.0          Rock
# 942                                    Live Through This   10.0          Rock
# 1057   Girly-Sound to Guyville: The 25th Anniversary ...   10.0          Rock
# 1070                                  Trout Mask Replica   10.0  Experimental
# 1224                                            Nebraska   10.0          Rock
# 1543                                   Master of Puppets   10.0         Metal
# 1683                                   The Queen Is Dead   10.0          Rock
# 2035                            Appetite for Destruction   10.0          Rock
# 2095               Purple Rain Deluxe — Expanded Edition   10.0       Pop/R&B
# 2109                       OK Computer OKNOTOK 1997 2017   10.0          Rock
# 2177                                   Supreme Clientele   10.0           Rap
# 2431                       Bach: The Goldberg Variations   10.0          Jazz
# 2493                                        Ready to Die   10.0           Rap
# 2499                         Either/Or: Expanded Edition   10.0          Rock
# 2533                                 Weezer (Blue Album)   10.0          Rock
# 2612                                           Homogenic   10.0    Electronic
# 2691                                Germfree Adolescents   10.0          Rock
# 2907                                           Metal Box   10.0          Rock
# 2916                                 Blood on the Tracks   10.0          Rock
# 3071                                 Another Green World   10.0  Experimental
# 3167                            Songs in the Key of Life   10.0       Pop/R&B
# 3246                                   The Philips Years   10.0          Jazz
# 3370                                 Tonight's the Night   10.0          Rock
# 3422                                      Hounds of Love   10.0       Pop/R&B
# ...                                                  ...    ...           ...
# 7357                                             Rumours   10.0          Rock
# 7417                                            Illmatic   10.0           Rap
# 7440                                 Donuts (45 Box Set)   10.0           Rap
# 7505                                              Voodoo   10.0       Pop/R&B
# 7580                            The Disintegration Loops   10.0  Experimental
# 7965             Liquid Swords: Chess Box Deluxe Edition   10.0           Rap
# 8208           Isn't Anything / Loveless / EPs 1988-1991   10.0  Experimental
# 8677                Tago Mago [40th Anniversary Edition]   10.0  Experimental
# 8803                                  The Smile Sessions   10.0          Rock
# 8843                        Laughing Stock / Mark Hollis   10.0          Rock
# 8933                Nevermind [20th Anniversary Edition]   10.0          Rock
# 9782                       Emergency & I [Vinyl Reissue]   10.0          Rock
# 9877                   My Beautiful Dark Twisted Fantasy   10.0           Rap
# 9941   Pinkerton [Deluxe Edition] / Death to False Metal   10.0          Rock
# 10421                    Disintegration [Deluxe Edition]   10.0          Rock
# 10496                 Exile on Main St. [Deluxe Edition]   10.0          Rock
# 10756                                Quarantine the Past   10.0          Rock
# 10776  Ladies and Gentlemen We are Floating in Space ...   10.0  Experimental
# 11299                                    The Stone Roses   10.0          Rock
# 11302                                         Abbey Road   10.0          Rock
# 11304                                        The Beatles   10.0          Rock
# 11306                               Magical Mystery Tour   10.0          Rock
# 11307              Sgt. Pepper's Lonely Hearts Club Band   10.0          Rock
# 11308                                           Revolver   10.0          Rock
# 11309                                        Rubber Soul   10.0          Rock
# 11315                               Stereo Box / In Mono   10.0          Rock
# 11360                  Kid A: Special Collectors Edition   10.0          Rock
# 11520                         Reckoning [Deluxe Edition]   10.0          Rock
# 11863                          Histoire de Melody Nelson   10.0       Pop/R&B
# 12004                                    Paul's Boutique   10.0           Rap
#
#                                                   review best  \
# 176    each sunday pitchfork takes an indepth look at...    0
# 239    each sunday pitchfork takes an indepth look at...    0
# 456    each sunday pitchfork takes an indepth look at...    0
# 490    best new reissue newly reissued on vinyl bikin...    1
# 556    each sunday pitchfork takes an indepth look at...    0
# 581    each sunday pitchfork takes an indepth look at...    0
# 916    each sunday pitchfork takes an indepth look at...    0
# 942    each sunday pitchfork takes an indepth look at...    0
# 1057   best new reissue liz phair’s indelible essenti...    1
# 1070   best new reissue captain beefheart’s 1969 mast...    1
# 1224   each sunday pitchfork takes an indepth look at...    0
# 1543   best new reissue in 1986 metallica released in...    1
# 1683   newly reissued as a boxed set the smiths’ 1986...    0
# 2035   the debut from guns n roses was a watershed mo...    0
# 2095   best new reissue in 1984 purple rain turned pr...    1
# 2109   best new reissue twenty years on radiohead rev...    1
# 2177   an unrivaled classic supreme clientele marked ...    0
# 2431   1 / 2 albums two virtuosic performances of a b...    0
# 2493   today we commemorate the 20th anniversary of t...    0
# 2499   best new reissue the 20th anniversary remaster...    1
# 2533   weezer’s 1994 debut filled with geeky humor de...    0
# 2612   homogenic embraced all of björk’s most provoca...    0
# 2691   xray spex’s debut album is a brash vivid maste...    0
# 2907   best new reissue pils second album metal box i...    1
# 2916   bob dylan’s moody 1975 epic is often referred ...    0
# 3071   brian eno has done everything from producing h...    0
# 3167   songs in the key of life was the culmination o...    0
# 3246   1 / 7 albums the philips years is a humble tit...    0
# 3370   neil youngs tonights the night is a harrowing ...    0
# 3422   with her selfproduced fifth album kate bush be...    0
# ...                                                  ...  ...
# 7357   best new reissue upon its release in 1977 rumo...    1
# 7417   best new reissue the 1994 hiphop landmark is r...    1
# 7440   best new reissue the songs on j dillas signatu...    1
# 7505   best new reissue twelve years since dangelo re...    1
# 7580   best new reissue the four volumes of william b...    1
# 7965   best new reissue as a solo artist gza was esse...    1
# 8208   best new reissue best new reissue best new rei...    1
# 8677   cans 1971 album tago mago freshly reissued in ...    0
# 8803   best new reissue conceived recorded and ultima...    1
# 8843   best new reissue best new reissue 1 / 2 albums...    1
# 8933   twenty years on the album that changed the cou...    0
# 9782   best new reissue one of the alltime great indi...    1
# 9877   best new music kanyes big year culminates in a...    1
# 9941   best new reissue 1 / 2 albums weezers overlook...    1
# 10421  best new reissue the cure’s 1989 album release...    1
# 10496  best new reissue the 1972 classic is given a r...    1
# 10756  best new reissue the first careerspanning pave...    1
# 10776  best new reissue this new deluxe limited produ...    1
# 11299  best new reissue a badly needed remaster of th...    1
# 11302  the perfect ending to a recording career this ...    0
# 11304  indulgent sprawling overflowing with ideas and...    0
# 11306  the only american release to become part of th...    0
# 11307  though it has perhaps slipped in estimation si...    0
# 11308  as they devoted more time to the studio the be...    0
# 11309  the beatles first undisputed masterpiece is th...    0
# 11315  best new reissue best new reissue 1 / 2 albums...    1
# 11360  best new reissue capitol follows its excavatio...    1
# 11520  best new reissue the expanded reissues of albu...    1
# 11863  best new reissue almost unbelievably the frenc...    1
# 12004  best new reissue the beastie boys’ landmark se...    1
#
#                     date rating
# 176      February 3 2019      1
# 239      January 13 2019      1
# 456      October 21 2018      1
# 490      October 11 2018      1
# 556    September 23 2018      1
# 581    September 16 2018      1
# 916         June 10 2018      1
# 942          June 3 2018      1
# 1057          May 2 2018      1
# 1070       April 28 2018      1
# 1224       March 18 2018      1
# 1543     December 2 2017      1
# 1683     October 22 2017      1
# 2035        July 16 2017      1
# 2095        June 26 2017      1
# 2109        June 22 2017      1
# 2177         June 4 2017      1
# 2431       March 26 2017      1
# 2493        March 9 2017      1
# 2499        March 7 2017      1
# 2533    February 26 2017      1
# 2612     February 5 2017      1
# 2691     January 15 2017      1
# 2907     November 1 2016      1
# 2916     October 30 2016      1
# 3071   September 18 2016      1
# 3167      August 21 2016      1
# 3246        July 30 2016      1
# 3370        June 26 2016      1
# 3422        June 12 2016      1
# ...                  ...    ...
# 7357     February 8 2013      1
# 7417     January 23 2013      1
# 7440     January 16 2013      1
# 7505    December 12 2012      1
# 7580    November 19 2012      1
# 7965        July 27 2012      1
# 8208         May 11 2012      1
# 8677     December 9 2011      1
# 8803     November 2 2011      1
# 8843     October 21 2011      1
# 8933   September 27 2011      1
# 9782     January 11 2011      1
# 9877    November 22 2010      1
# 9941     November 3 2010      1
# 10421       June 10 2010      1
# 10496        May 19 2010      1
# 10756       March 8 2010      1
# 10776       March 2 2010      1
# 11299  September 11 2009      1
# 11302  September 10 2009      1
# 11304  September 10 2009      1
# 11306   September 9 2009      1
# 11307   September 9 2009      1
# 11308   September 9 2009      1
# 11309   September 9 2009      1
# 11315   September 7 2009      1
# 11360     August 25 2009      1
# 11520        July 2 2009      1
# 11863      March 26 2009      1
# 12004   February 13 2009      1
#
# [79 rows x 9 columns]

# %%
#Count the number of perfect scores by artist
perf_counts = perfect['artist'].value_counts()

# %%
perf_counts
# Out:
# The Beatles                             7
# The Velvet Underground                  3
# Prince                                  3
# Radiohead                               2
# Nirvana                                 2
# David Bowie                             2
# The Rolling Stones                      2
# Prince / The Revolution                 2
# Metallica                               2
# Weezer                                  2
# Glenn Gould                             1
# William Basinski                        1
# Hole                                    1
# Public Image Ltd                        1
# J Dilla                                 1
# Beastie Boys                            1
# Mobb Deep                               1
# Guns N' Roses                           1
# Fleetwood Mac                           1
# John Coltrane                           1
# Björk                                   1
# The Beach Boys                          1
# Pavement                                1
# Kanye West                              1
# Can                                     1
# The Cure                                1
# De La Soul                              1
# Nas                                     1
# Nina Simone                             1
# Captain Beefheart and His Magic Band    1
#                                        ..
# Alice Coltrane                          1
# Talking Heads                           1
# The Smiths                              1
# Serge Gainsbourg                        1
# The Stone Roses                         1
# Liz Phair                               1
# D’Angelo                                1
# Kate Bush                               1
# Brian Eno                               1
# Ghostface Killah                        1
# X-Ray Spex                              1
# The Band                                1
# Stevie Wonder                           1
# Bob Dylan                               1
# PJ Harvey                               1
# Bikini Kill                             1
# Van Morrison                            1
# Talk Talk / Mark Hollis                 1
# Elliott Smith                           1
# The Dismemberment Plan                  1
# Bruce Springsteen                       1
# Michael Jackson                         1
# R.E.M.                                  1
# Spiritualized                           1
# Neil Young                              1
# The Notorious B.I.G.                    1
# My Bloody Valentine                     1
# Slint                                   1
# Public Enemy                            1
# Talk Talk                               1
# Name: artist, Length: 62, dtype: int64

# %%
perf_artists = perfect.artist.unique()

# %%
#Create data frame with artists who have multiple perfect scores
perf_multi = pd.DataFrame(data=None, index=None, columns=['Artist','Albums'])
for i in range(len(perf_counts)):
    if perf_counts.values[i] > 1:
        perf_multi = perf_multi.append({'Artist' : perf_counts.index[i], 'Albums' : perf_counts.values[i]}, ignore_index=True)

# %%
perf_multi
# Out:
#                     Artist Albums
# 0              The Beatles      7
# 1   The Velvet Underground      3
# 2                   Prince      3
# 3                Radiohead      2
# 4                  Nirvana      2
# 5              David Bowie      2
# 6       The Rolling Stones      2
# 7  Prince / The Revolution      2
# 8                Metallica      2
# 9                   Weezer      2

# %%
#Create bar graph of artists who have multiple perfect scores and the total perfect score per artist
ax = sns.barplot(x="Artist", y="Albums", data=perf_multi)
ax.set_xticklabels(ax.get_xticklabels(), rotation=80)
# Out:
# [Text(0, 0, 'The Beatles'),
#  Text(0, 0, 'The Velvet Underground'),
#  Text(0, 0, 'Prince'),
#  Text(0, 0, 'Radiohead'),
#  Text(0, 0, 'Nirvana'),
#  Text(0, 0, 'David Bowie'),
#  Text(0, 0, 'The Rolling Stones'),
#  Text(0, 0, 'Prince / The Revolution'),
#  Text(0, 0, 'Metallica'),
#  Text(0, 0, 'Weezer')]

# %%
rating_counts = pitchfork_df['rating'].value_counts()

# %%
rating_counts
# Out:
#  1    7667
#  0    4309
# -1     178
# Name: rating, dtype: int64

# %%
good_albums = pd.DataFrame(data=None, index=None, columns=pitchfork_df.columns)
ok_albums = pd.DataFrame(data=None, index=None, columns=pitchfork_df.columns)
bad_albums = pd.DataFrame(data=None, index=None, columns=pitchfork_df.columns)
for i in range(len(pitchfork_df)):
    if pitchfork_df['rating'][i] == 1:
        good_albums = good_albums.append(pitchfork_df.loc[i])
    if pitchfork_df['rating'][i] == 0:
        ok_albums = ok_albums.append(pitchfork_df.loc[i])
    if pitchfork_df['rating'][i] == -1:
        bad_albums = bad_albums.append(pitchfork_df.loc[i])

# %%
bad_albums.sort_values(by='score', ascending=True)
# Out:
#       index                                         artist  \
# 12093  2955                                Various Artists
# 12143  3005                    Black Rebel Motorcycle Club
# 6632    538                                         Pixies
# 8808   2714                           Metallica / Lou Reed
# 8681   2587                                     Mac Miller
# 12025  2887                                   Psychic Ills
# 9932    794                          Ghostland Observatory
# 11994  2856                                       N.A.S.A.
# 8702   2608                               Childish Gambino
# 448     448                                Greta Van Fleet
# 11913  2775                                Various Artists
# 11499  2361                                        50 Cent
# 8461   2367                                 The Ting Tings
# 10282  1144                                     Ninjasonik
# 5187   2139                                Various Artists
# 7336   1242                                     Paul Banks
# 9540    402                                       Jessie J
# 6272    178                                         Pixies
# 4713   1665                                 Mumford & Sons
# 3131     83                               Prophets of Rage
# 5602   2554                                Various Artists
# 10757  1619                                    Jaguar Love
# 11374  2236                                   Amanda Blank
# 10807  1669                                 Mumford & Sons
# 9089   2995                                    Chiddy Bang
# 8707   2613                                       The Fall
# 11316  2178                              The Entrance Band
# 11030  1892                                    The Bravery
# 11768  2630                                     Asher Roth
# 9679    541                                      The Dears
# ...     ...                                            ...
# 1382   1382                              Justin Timberlake
# 10715  1577                                  Awesome Color
# 9657    519                                   MillionYoung
# 10658  1520                                   Turin Brakes
# 3366    318                             The Avett Brothers
# 10813  1675  Everybody Was in the French Resistance...Now!
# 10113   975                          Everything Everything
# 9458    320                         The Head and the Heart
# 10455  1317                                  Born Ruffians
# 10158  1020                              We Are Scientists
# 11133  1995                                         Tiësto
# 9737    599                                  Cold War Kids
# 7182   1088                                      Lil Wayne
# 7398   1304                                    Pillowfight
# 6355    261                             Sebastien Grainger
# 10585  1447                               Rufus Wainwright
# 10915  1777                                           Eels
# 11865  2727                    Mt. St. Helens Vietnam Band
# 10818  1680                               Juliana Hatfield
# 8596   2502                                    Lamb of God
# 4583   1535                                 Mates of State
# 4522   1474                                           Tyga
# 8779   2685                                        Misfits
# 8820   2726                                      Deer Tick
# 11171  2033                             Buckshot / KRS-One
# 3929    881                                     Tory Lanez
# 11236  2098                                            Múm
# 11523  2385                     Street Sweeper Social Club
# 5250   2202                                 Dillon Francis
# 5542   2494                                   Nachtmystium
#
#                                                    album  score         genre  \
# 12093                                Johnny Cash Remixed    0.2          Misc
# 12143                                 The Effects of 333    0.4          Rock
# 6632                                                EP-1    1.0          Rock
# 8808                                                Lulu    1.0         Metal
# 8681                                     Blue Slide Park    1.0           Rap
# 12025                                         Mirror Eye    1.4  Experimental
# 9932                                     Codename: Rondo    1.5    Electronic
# 11994                               The Spirit of Apollo    1.6           Rap
# 8702                                                Camp    1.6           Rap
# 448                          Anthem of the Peaceful Army    1.6          Rock
# 11913  Just Like Heaven: A Tribute to the Cure / Perf...    1.7          Misc
# 11499                                          War Angel    1.8       Pop/R&B
# 8461                           Sounds From Nowheresville    1.8    Electronic
# 10282                                   Art School Girls    1.9           Rap
# 5187                                            Shady XV    2.0          Misc
# 7336       Everybody on My Dick Like They Supposed to Be    2.0          Rock
# 9540                                         Who You Are    2.0    Electronic
# 6272                                                EP-2    2.0          Rock
# 4713                                         Wilder Mind    2.0          Rock
# 3131                                 The Party's Over EP    2.0          Rock
# 5602                                 Wish I Was Here OST    2.0          Misc
# 10757                                      Hologram Jams    2.0    Electronic
# 11374                                         I Love You    2.0    Electronic
# 10807                                       Sigh No More    2.1          Rock
# 9089                            Peanut Butter and Swelly    2.1           Rap
# 8707                                         Ersatz G.B.    2.2          Rock
# 11316                                  The Entrance Band    2.2          Rock
# 11030                                     Stir the Blood    2.3    Electronic
# 11768                          Asleep in the Bread Aisle    2.4           Rap
# 9679                                 Degeneration Street    2.4          Rock
# ...                                                  ...    ...           ...
# 1382                                    Man of the Woods    3.8       Pop/R&B
# 10715                                       Massa Hypnos    3.8          Rock
# 9657                                          Replicants    3.8    Electronic
# 10658                                          Outbursts    3.8          Rock
# 3366                                        True Sadness    3.8          Rock
# 10813                          Fixin' the Charts, Vol. 1    3.8       Pop/R&B
# 10113                                          Man Alive    3.8          Rock
# 9458                              The Head and the Heart    3.8          Rock
# 10455                                             Say It    3.8          Rock
# 10158                                            Barbara    3.8    Electronic
# 11133                                       Kaleidoscope    3.8    Electronic
# 9737                                       Mine Is Yours    3.9    Electronic
# 7182                           I Am Not a Human Being II    3.9           Rap
# 7398                                         Pillowfight    3.9          Misc
# 6355                                   Yours to Discover    3.9          Rock
# 10585                All Days are Nights: Songs for Lulu    3.9          Rock
# 10915                                          End Times    3.9          Rock
# 11865                        Mt. St. Helens Vietnam Band    3.9          Rock
# 10818                                       Peace & Love    3.9          Rock
# 8596                                          Resolution    3.9         Metal
# 4583                          You're Going to Make It EP    3.9          Rock
# 4522                        The Gold Album: 18th Dynasty    3.9           Rap
# 8779                                    The Devil's Rain    3.9         Metal
# 8820                                   Divine Providence    3.9          Rock
# 11171                                    Survival Skills    3.9         Metal
# 3929                        The New Toronto / Chixtape 3    3.9           Rap
# 11236                 Sing Along to Songs You Don't Know    3.9    Electronic
# 11523                         Street Sweeper Social Club    3.9         Metal
# 5250                           Money Sucks, Friends Rule    3.9    Electronic
# 5542                            The World We Left Behind    3.9         Metal
#
#                                                   review best  \
# 12093  totally inessential ive been scouring the book...    0
# 12143  this is no shit a background noise record rele...    0
# 6632   the oncemighty pixies debase their legacy with...    0
# 8808   lou reed and metallicas collaborative album ba...    0
# 8681   mac millers debut is the first independently d...    0
# 12025  contemporaries of gang gang dance and black di...    0
# 9932   the austin duos fourth album fails as both hum...    0
# 11994  credit where its due sam spiegel and zé gonzal...    0
# 8702   community star donald glovers fourth hiphop co...    0
# 448    the debut from the young michigan rock band is...    0
# 11913  1 / 2 albums did you want three discs worth of...    0
# 11499  this internetonly mixtape finds 50 cent trying...    0
# 8461   on the english duos genrehopping sophomore alb...    0
# 10282  its like ironic hipster rap and bloghouse neve...    0
# 5187   eminems music has been unrelievedly awful now ...    0
# 7336   on his debut mixtape the interpol frontman doe...    0
# 9540   uk pop star jessie j is charmless banal vapid ...    0
# 6272   the resurrected pixies ep2 dates from the same...    0
# 4713   with the production help of james ford member ...    0
# 3131   the new rage against the machine/public enemy/...    0
# 5602   zach braffs new film has been touted as the sp...    0
# 10757  these former blood brothers are now a duo with...    0
# 11374  lady gaga minus the tunes ambition or sense of...    0
# 10807  west london bands faux family business actuall...    0
# 9089   philly rap duo chiddy bangs mixtape pairs a di...    0
# 8707   the falls 29th studio album raises questions l...    0
# 11316  guy blakeslee recruits a rhythm section à la t...    0
# 11030  after a misstep of a second album these modern...    0
# 11768  yall act like youve never seen a white person ...    0
# 9679   dears founder murray a lightburn continues to ...    0
# ...                                                  ...  ...
# 1382   justin timberlake’s fifth album is a huge miss...    0
# 10715  ecstatic peace band continues to mine sludgy d...    0
# 9657   florida chillwave artist follows last years be...    0
# 10658  its the return of turin brakes back with more ...    0
# 3366   it’s fitting that the avett brothers’ most dis...    0
# 10813  art bruts eddie argos teams with dyan valdés o...    0
# 10113  future mercury prize contenders continue to ma...    0
# 9458   sub pop rereleases this seattle groups debut w...    0
# 10455  after a promising debut warps spazzpop band so...    0
# 10158  popular in the uk and basically ignored at hom...    0
# 11133  trance superstar trades voyages into the smile...    0
# 9737   blogrock stars make a bid for crossover succes...    0
# 7182   the possibility that lil waynes new album coul...    0
# 7398   over a career spanning two decades dan the aut...    0
# 6355   death from above drummer/vocalist sebastien gr...    0
# 10585  the talented pop singer flirts with outright s...    0
# 10915  mark oliver everett returns with another recor...    0
# 11865  mshvb sound like a bunch of talented precociou...    0
# 10818  ten albums into her solo career the altrock ve...    0
# 8596   the seventh album from one of americas few maj...    0
# 4583   it’s been four years since the pop duo mates o...    0
# 4522   as tyga would tell it the gold album is his se...    0
# 8779   misfits first album of new material in 12 year...    0
# 8820   on the providence roots rockers previous lps y...    0
# 11171  nyc rap vets offer a surprise collaboration wi...    0
# 3929   1 / 2 albums after years of drakewave and clon...    0
# 11236  icelandic band remains pretty obsessed with th...    0
# 11523  rage against the machines tom morello teams wi...    0
# 5250   money sucks friends rule is dillon francis fir...    0
# 5542   what could be the final album from black metal...    0
#
#                     date rating
# 12093    January 20 2009     -1
# 12143     January 6 2009     -1
# 6632    September 6 2013     -1
# 8808     November 1 2011     -1
# 8681     December 8 2011     -1
# 12025    February 6 2009     -1
# 9932     November 4 2010     -1
# 11994   February 18 2009     -1
# 8702     December 2 2011     -1
# 448      October 23 2018     -1
# 11913      March 12 2009     -1
# 11499        July 9 2009     -1
# 8461        March 1 2012     -1
# 10282       July 21 2010     -1
# 5187    November 26 2014     -1
# 7336    February 14 2013     -1
# 9540       March 25 2011     -1
# 6272     January 10 2014     -1
# 4713          May 7 2015     -1
# 3131      August 31 2016     -1
# 5602        July 22 2014     -1
# 10757       March 5 2010     -1
# 11374     August 13 2009     -1
# 10807   February 19 2010     -1
# 9089       August 4 2011     -1
# 8707     December 1 2011     -1
# 11316   September 4 2009     -1
# 11030   November 30 2009     -1
# 11768      April 22 2009     -1
# 9679    February 15 2011     -1
# ...                  ...    ...
# 1382     February 2 2018     -1
# 10715      March 18 2010     -1
# 9657    February 21 2011     -1
# 10658       April 2 2010     -1
# 3366        June 27 2016     -1
# 10813   February 18 2010     -1
# 10113  September 15 2010     -1
# 9458       April 18 2011     -1
# 10455        June 1 2010     -1
# 10158     August 25 2010     -1
# 11133    October 28 2009     -1
# 9737     January 26 2011     -1
# 7182       March 29 2013     -1
# 7398     January 28 2013     -1
# 6355    November 25 2013     -1
# 10585      April 23 2010     -1
# 10915    January 21 2010     -1
# 11865      March 25 2009     -1
# 10818   February 17 2010     -1
# 8596     January 24 2012     -1
# 4583        June 15 2015     -1
# 4522         July 1 2015     -1
# 8779     November 8 2011     -1
# 8820     October 27 2011     -1
# 11171    October 16 2009     -1
# 3929     January 21 2016     -1
# 11236  September 29 2009     -1
# 11523        July 1 2009     -1
# 5250     November 7 2014     -1
# 5542       August 7 2014     -1
#
# [178 rows x 9 columns]

# %%
bad_albums['artist'].value_counts().head(20)
# Out:
# Various Artists                                  6
# Eels                                             3
# Mumford & Sons                                   2
# Mt. St. Helens Vietnam Band                      2
# WHY?                                             2
# Miles Kane                                       2
# Pixies                                           2
# The Chainsmokers                                 2
# Tyga                                             2
# Sun Kil Moon                                     2
# Night Beds                                       1
# The Gaslight Anthem                              1
# Everybody Was in the French Resistance...Now!    1
# The Sounds                                       1
# Dressy Bessy                                     1
# Native                                           1
# Bloc Party                                       1
# Au Revoir Simone                                 1
# Boris / Ian Astbury                              1
# The Ting Tings                                   1
# Name: artist, dtype: int64

# %%
bad_albums['genre'].value_counts()
# Out:
# Rock            69
# Electronic      31
# Rap             29
# Misc            17
# Metal           14
# Pop/R&B         10
# Experimental     6
# Folk/Country     2
# Name: genre, dtype: int64

# %%
pitchfork_df.groupby(['rating'])

# %%
rating_counts.sum()
# Out:
# 12154
